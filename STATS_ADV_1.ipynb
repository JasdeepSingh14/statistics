# %% [markdown]
# ***`Question 1: What is a random variable in probability theory?`***
#
# ***`ANSWER- `***
#
# In probability theory, a random variable is a variable that takes on different numerical values based on the outcomes of a random experiment. It provides a way to quantify uncertainty by assigning a number to each possible outcome in a sample space.
#
#
# ***`Question 2: What are the types of random variables?`***
#
# ***`ANSWER-`***
#
# Randon variables are of 2 types-
# 1. Discrete Random Variable
# 2. Continuous Random Variable
#
#
# ***`Question 3: Explain the difference between discrete and continuous distributions.`***
#
# ***`Answer:`***
#
# 1. Discrete Random Variable:
# A random variable is said to be discrete if it can take only a finite or countably infinite number of distinct values.
# Examples:
# Number of heads when tossing three coins (possible values: 0, 1, 2, 3).
# Number of students present in a class on a given day.
#
# 2. Continuous Random Variable:
# A random variable is continuous if it can take any value within a given range or interval. These variables are usually measured, not counted.
# Examples:
# Height of students in a class.
# Time taken for a car to cover a fixed distance.
#
#
# ***`Question 4: What is a binomial distribution, and how is it used in probability?`***
#
# ***`ANSWER- `***
#
# A random variable X is said to follow a binomial distribution if it represents the number of successes in n independent trials, each with a constant probability of success p.
#
# It is denoted as:
# X ∼ B(n,p)
#
#
# n = number of trials
# p = probability of success in one trial
# q=1−p = probability of failure
#
# -----Uses of Binomial Distribution in Probability:
#
# 1. The binomial distribution is widely used to model situations involving repeated independent experiments with binary outcomes. Examples include:
#
# 2. Determining the probability of getting a certain number of heads in coin tosses.
#
# 3. Calculating the chance that a specific number of products are defective in a batch.
#
# ***`Question 5: What is the standard normal distribution, and why is it important?`***
#
# ***`Answer:`***
#
# The Standard Normal Distribution is a special type of continuous probability distribution that plays a central role in statistics and probability theory. It is a specific form of the normal distribution where the mean (μ) is 0 and the standard deviation (σ) is 1. It is also known as the Z-distribution
#
# **Importance of the Standard Normal Distribution:**
#
# 1. Simplifies probability calculations:
# Standard normal tables provide the probability that a standard normal variable is less than a given value of Z.
#
# 2. Basis for hypothesis testing:
# Many statistical tests (e.g., Z-test, t-test) are based on standard normal distribution properties.
#
# 3. By converting data to Z-scores, we can compare values from different normal distributions.
#
# ***`Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?`***
#
# ***`ANSWER-`***
#
# When a large number of independent random samples are drawn from any population with a finite mean (μ) and  variance (σ²), the sampling distribution of the sample mean will approach a normal distribution as the sample size increases, regardless of the shape of the original population.
#
# **Importance of the Central Limit Theorem:**
#
# 1. Foundation for inferential statistics.
# 2. Estimation and hypothesis testing.
# 3. Simplifies complex data.
# 4. Predicting sample behavior.
#
#
# ***`Question 7: What is the significance of confidence intervals in statistical analysis?`***
#
# ***`Answer: `***
#
# A confidence interval is a range calculated from sample data that is likely to contain the true population parameter with a certain level of confidence.
#
# A confidence interval (CI) is a fundamental concept in statistical analysis that provides a range of values within which the true population parameter (such as the mean or proportion) is likely to lie, based on sample data.
# It is also Useful in decision making and hypothesis testing
#
# ***`Question 8: What is the concept of expected value in a probability distribution?`***
#
# ***`Answer- `***
#
# The expected value (also called the mathematical expectation, mean, or average) of a probability distribution is a key concept in probability and statistics. It represents the average value of a random variable after repeating an experiment many times.
# it tells us what value we can expect on average when an experiment is repeated under the same conditions. It measures central tendency and helps in decision making.

# %%
'''Question 9: Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and
 standard deviation = 5. Compute its mean and standard deviation using NumPy,
 and draw a histogram to visualize the distribution.(Include your Python code and output in the code box below.)'''

import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 random numbers from a normal distribution
mean = 50
std_dev = 5
data = np.random.normal(mean, std_dev, 1000)


computed_mean = np.mean(data)
computed_std = np.std(data)


print("Computed Mean:", computed_mean)
print("Computed Standard Deviation:", computed_std)


plt.figure(figsize=(8,5))
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Normally Distributed Random Numbers')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# Computed Mean: 50.15735183510555
# Computed Standard Deviation: 4.935287483602601

# %% [markdown]
# ***`Question 10: You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend. daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255, 235, 260, 245, 250, 225, 270, 265, 255, 250, 260] ● Explain how you would apply the Central Limit Theorem to estimate the average sales with a 95% confidence interval. ● Write the Python code to compute the mean sales and its confidence interval. (Include your Python code and output in the code box below.) `***
#
# ***`ANSWER-`***
#
# The Central Limit Theorem (CLT) states that if we take repeated random samples from a population, the sampling distribution of
# the sample mean will approach a normal distribution, regardless of the shape of the original data provided the
# sample size is large enough  𝑛>30.
#
# 1. we use the CLT concept to estimate the average daily sales and construct a 95% confidence interval (CI) for the true mean sales.

# %%
import numpy as np
import scipy.stats as stats

# Given sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]


mean_sales = np.mean(daily_sales)
std_sales = np.std(daily_sales, ddof=1)
n = len(daily_sales)

# 95% confidence interval using CLT
confidence_level = 0.95
z_value = stats.norm.ppf(1 - (1 - confidence_level)/2)
margin_of_error = z_value * (std_sales / np.sqrt(n))

lower_bound = mean_sales - margin_of_error
upper_bound = mean_sales + margin_of_error


print("Mean Sales:", mean_sales)
print("Standard Deviation:", std_sales)
print("95% Confidence Interval: ({:.2f}, {:.2f})".format(lower_bound, upper_bound))
# Out:
# Mean Sales: 248.25
# Standard Deviation: 17.26534405284638
# 95% Confidence Interval: (240.68, 255.82)
